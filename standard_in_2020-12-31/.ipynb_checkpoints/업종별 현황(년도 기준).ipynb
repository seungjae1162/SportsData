# %%
#필요한 라이브러리(패키지) import

import pandas as pd
import numpy as np
import csv

# 시각화 패키지
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'

# %matplotlib inline

# %%
# LOCALDATA의 체육시설 업종(https://www.localdata.go.kr/devcenter/dataDown.do?menuNo=20001) 16개 CSV파일 다운
## EXCEL에서 필요없는 칼럼 삭제(37개 -> 14개)
## CSV파일 읽음

df= pd.read_csv("/Users/seung/Desktop/standard_in_2020-12-17/csv/disclosed_sports_service.csv", encoding="utf-8")

# %%
df14 = df['폐업년도'].value_counts()

# %%
df14 = pd.DataFrame(df13)
df14.columns = ['폐업 수']
df15 = df14.T
df15
# Out:
# 폐업년도  2016  2017  2018  2019  2020
# 폐업 수  1871  2286  3213  3239  3204

# %%
#년도별 폐업 갯수 막대그래프화

ax = sns.barplot(data=df15)
ax.set_xlabel('지역별 폐업 총 수')

plt.show()

# %%
#excel에서 년도별로 필터처리하여 csv로 저장

years2016_1= pd.read_csv("/Users/seung/Desktop/standard_in_2020-12-17/csv/2016_폐업_업종.csv", encoding="utf-8")
years2017_1= pd.read_csv("/Users/seung/Desktop/standard_in_2020-12-17/csv/2017_폐업_업종.csv", encoding="utf-8")
years2018_1= pd.read_csv("/Users/seung/Desktop/standard_in_2020-12-17/csv/2018_폐업_업종.csv", encoding="utf-8")
years2019_1= pd.read_csv("/Users/seung/Desktop/standard_in_2020-12-17/csv/2019_폐업_업종.csv", encoding="utf-8")
years2020_1= pd.read_csv("/Users/seung/Desktop/standard_in_2020-12-17/csv/2020_폐업_업종.csv", encoding="utf-8")

# %%
years2016.head(10)
# Out:
#          사업장명 문화체육업종명           영업상태명 상세영업상태명  폐업년도      폐업일자   위치  \
# 0         학여울    무도장업  취소/말소/만료/정지/중지    직권말소  2016  20161031   서울
# 1      A1 당구장    무도장업  취소/말소/만료/정지/중지    직권말소  2016  20161010   인천
# 2     중문 승마클럽    승마장업  취소/말소/만료/정지/중지    직권말소  2016  20160316   제주
# 3       성심체육관   체육도장업  취소/말소/만료/정지/중지    직권말소  2016  20160513   경상
# 4     운화병천체육관   체육도장업  취소/말소/만료/정지/중지    직권말소  2016  20161221   충청
# 5     이이캔태권도장   체육도장업  취소/말소/만료/정지/중지    직권말소  2016  20160527   충청
# 6     대한태권도스쿨   체육도장업  취소/말소/만료/정지/중지    직권말소  2016  20160801   전라
# 7    성문관정도체육관   체육도장업  취소/말소/만료/정지/중지    직권말소  2016  20160801  NaN
# 8       해남체육관   체육도장업  취소/말소/만료/정지/중지    직권말소  2016  20160801  NaN
# 9  해남강호태권도체육관   체육도장업  취소/말소/만료/정지/중지    직권말소  2016  20160801   전라
#
#                               도로명전체주소
# 0            서울특별시 종로구 종로66길 35 (숭인동)
# 1             인천광역시 미추홀구 주안서로 6 (주안동)
# 2      제주특별자치도 서귀포시 중문관광로 287-7 (중문동)
# 3  경상남도 창원시 성산구 원이대로473번길 20-23 (반림동)
# 4         충청남도 천안시 동남구 병천면 아우내장터3길 22
# 5       충청남도 천안시 동남구 풍세로 1010-6 (청수동)
# 6                 전라남도 해남군 화원면 금평길 11
# 7                                 NaN
# 8                                 NaN
# 9                전라남도 해남군 해남읍 구교2길 10

# %%
years2016= years2016_1.drop(['영업상태명','상세영업상태명'],axis=1)
years2017= years2017_1.drop(['영업상태명','상세영업상태명'],axis=1)
years2018= years2018_1.drop(['영업상태명','상세영업상태명'],axis=1)
years2019= years2019_1.drop(['영업상태명','상세영업상태명'],axis=1)
years2020= years2020_1.drop(['영업상태명','상세영업상태명'],axis=1)

# %%
YEAR2016.pd.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-276-8b7ec180f68c> in <module>
# ----> 1 YEAR2016.pd.DataFrame()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'pd'

# %%
YEAR2016 = years2016['위치'].value_counts()

YEAR2016.plot.barh()

# %%
YEAR2017 = years2017['위치'].value_counts()

YEAR2017.plot.barh()

# %%
YEAR2018 = years2018['위치'].value_counts()

YEAR2018.plot.barh()

# %%
YEAR2019 = years2019['위치'].value_counts()

YEAR2019.plot.barh()

# %%
YEAR2020 = years2020['위치'].value_counts()

YEAR2020.plot.barh()

# %%
# 2016년 폐업 수 1위 경기도, 2위 서울, 3위 경상도
# 1위~3위에서 어떤 체육 시설 폐업 갯수가 많은 지 조사 및 그래프화

## 2016년 1위 경기도
## 당구장업이 망한 갯수가 제일 많고, 체육도장업 및 골프연습장업이 2위, 3위를 함

# %%
#2016년도 각 지역별에 따른 조회 및 병합

gyeonggi = (years2016['위치']=='경기')
seoul = (years2016['위치']=='서울')
gyeongsang = (years2016['위치']=='경상')

gyeonggi2016 = years2016.loc[gyeonggi]
seoul2016 = years2016.loc[seoul]
gyeongsang2016 = years2016.loc[gyeongsang]

## 2016년 1위 경기도
## 1위 당구장업, 2위 체육도장업, 3위 골프연습장업

GG2016 = gyeonggi2016['문화체육업종명'].value_counts()
SO2016 = seoul2016['문화체육업종명'].value_counts()
GS2016 = gyeongsang2016['문화체육업종명'].value_counts()

G2016G = pd.DataFrame(GG2016)
S2016O = pd.DataFrame(SO2016)
G2016S = pd.DataFrame(GS2016)

G2016G.columns=['경기도']
S2016O.columns=['서울시']
G2016S.columns=['경상도']

G2016G.plot.barh()
S2016O.plot.barh()
G2016S.plot.barh()

# %%
# 2017년 폐업 수 1위 경기도, 2위 서울, 3위 경상도
# 1위~3위에서 어떤 체육 시설 폐업 갯수가 많은 지 조사 및 그래프화

## 2016년 1위 경기도
## 당구장업이 망한 갯수가 제일 많고, 체육도장업 및 골프연습장업이 2위, 3위를 함

# %%
#2017년도 각 지역별에 따른 조회 및 병합

gyeonggi = (years2017['위치']=='경기')
seoul = (years2017['위치']=='서울')
gyeongsang = (years2017['위치']=='경상')

gyeonggi2017 = years2017.loc[gyeonggi]
seoul2017 = years2017.loc[seoul]
gyeongsang2017 = years2017.loc[gyeongsang]


## 2017년 1위 경기도
## 1위 당구장업, 2위 체육도장업, 3위 골프연습장업

GG2017 = gyeonggi2017['문화체육업종명'].value_counts()
SO2017 = seoul2017['문화체육업종명'].value_counts()
GS2017 = gyeongsang2017['문화체육업종명'].value_counts()

G2017G = pd.DataFrame(GG2017)
S2017O = pd.DataFrame(SO2017)
G2017S = pd.DataFrame(GS2017)

G2017G.columns=['경기도']
S2017O.columns=['서울시']
G2017S.columns=['경상도']

G2017G.plot.barh()
S2017O.plot.barh()
G2017S.plot.barh()

# %%
# 2018년 폐업 수 1위 경기도, 2위 서울, 3위 경상도
# 1위~3위에서 어떤 체육 시설 폐업 갯수가 많은 지 조사 및 그래프화

## 2018년 1위 경기도
## 당구장업이 망한 갯수가 제일 많고, 체육도장업 및 골프연습장업이 2위, 3위를 함

# %%
#2018년도 각 지역별에 따른 조회 및 병합

gyeonggi = (years2018['위치']=='경기')
seoul = (years2018['위치']=='서울')
gyeongsang = (years2018['위치']=='경상')

gyeonggi2018 = years2018.loc[gyeonggi]
seoul2018 = years2018.loc[seoul]
gyeongsang2018 = years2018.loc[gyeongsang]


## 2018년 1위 경기도
## 1위 당구장업, 2위 체육도장업, 3위 골프연습장업

GG2018 = gyeonggi2018['문화체육업종명'].value_counts()
SO2018 = seoul2018['문화체육업종명'].value_counts()
GS2018 = gyeongsang2018['문화체육업종명'].value_counts()

G2018G = pd.DataFrame(GG2018)
S2018O = pd.DataFrame(SO2018)
G2018S = pd.DataFrame(GS2018)

G2018G.columns=['경기도']
S2018O.columns=['서울시']
G2018S.columns=['경상도']

G2018G.plot.barh()
S2018O.plot.barh()
# 2017년 폐업 수 1위 경기도, 2위 서울, 3위 경상도
# 1위~3위에서 어떤 체육 시설 폐업 갯수가 많은 지 조사 및 그래프화

## 2016년 1위 경기도
## 당구장업이 망한 갯수가 제일 많고, 체육도장업 및 골프연습장업이 2위, 3위를 함G2018S.plot.barh()

# %%
# 2019년 폐업 수 1위 경기도, 2위 서울, 3위 경상도
# 1위~3위에서 어떤 체육 시설 폐업 갯수가 많은 지 조사 및 그래프화

## 2019년 1위 경기도
## 당구장업이 망한 갯수가 제일 많고, 체육도장업 및 골프연습장업이 2위, 3위를 함

# %%
#2019년도 각 지역별에 따른 조회 및 병합

gyeonggi = (years2019['위치']=='경기')
seoul = (years2019['위치']=='서울')
gyeongsang = (years2019['위치']=='경상')

gyeonggi2019 = years2019.loc[gyeonggi]
seoul2019 = years2019.loc[seoul]
gyeongsang2019 = years2019.loc[gyeongsang]


## 2019년 1위 경기도
## 1위 당구장업, 2위 체육도장업, 3위 골프연습장업

GG2019 = gyeonggi2019['문화체육업종명'].value_counts()
SO2019 = seoul2019['문화체육업종명'].value_counts()
GS2019 = gyeongsang2019['문화체육업종명'].value_counts()

G2019G = pd.DataFrame(GG2019)
S2019O = pd.DataFrame(SO2019)
G2019S = pd.DataFrame(GS2019)

G2019G.columns=['경기도']
S2019O.columns=['서울시']
G2019S.columns=['경상도']

G2019G.plot.barh()
S2019O.plot.barh()
G2019S.plot.barh()

# %%
# 2020년 폐업 수 1위 경기도, 2위 서울, 3위 경상도
# 1위~3위에서 어떤 체육 시설 폐업 갯수가 많은 지 조사 및 그래프화

## 2020년 1위 경기도
## 당구장업이 망한 갯수가 제일 많고, 체육도장업 및 골프연습장업이 2위, 3위를 함

# %%
#2020년도 각 지역별에 따른 조회 및 병합

gyeonggi = (years2020['위치']=='경기')
seoul = (years2020['위치']=='서울')
gyeongsang = (years2020['위치']=='경상')

gyeonggi2020 = years2020.loc[gyeonggi]
seoul2020 = years2020.loc[seoul]
gyeongsang2020 = years2020.loc[gyeongsang]


## 2020년 1위 경기도
## 1위 당구장업, 2위 체육도장업, 3위 골프연습장업

GG2020 = gyeonggi2020['문화체육업종명'].value_counts()
SO2020 = seoul2020['문화체육업종명'].value_counts()
GS2020 = gyeongsang2020['문화체육업종명'].value_counts()

G2020G = pd.DataFrame(GG2020)
S2020O = pd.DataFrame(SO2020)
G2020S = pd.DataFrame(GS2020)

G2020G.columns=['경기도']
S2020O.columns=['서울시']
G2020S.columns=['경상도']

G2020G.plot.barh()
S2020O.plot.barh()
G2020S.plot.barh()

# %%
# 행,열 변환 .T 입력하면 됨

GYEONGGI2017 = G2017G.T
SEOUL2017 = S2017O.T
GYEONGSANG2017 = G2017S.T

# %%
S2017O.plot.pie(y='서울시',figsize=(5,5))
