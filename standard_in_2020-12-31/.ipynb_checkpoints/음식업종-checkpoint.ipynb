# %%
#필요한 라이브러리(패키지) import

import pandas as pd
import numpy as np
import csv

# 시각화 패키지
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'

# %matplotlib inline

# %%
# LOCALDATA의 체육시설 업종(https://www.localdata.go.kr/devcenter/dataDown.do?menuNo=20001) 16개 CSV파일 다운
## EXCEL에서 필요없는 칼럼 삭제(37개 -> 14개)
## CSV파일 읽음

df= pd.read_csv("/Users/seung/Desktop/standard_in_2020-12-31/csv/food.csv",encoding='cp949')
# Out:
# C:\Users\seung\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#               사업장명       업태구분명 개방서비스명     인허가일자 상세영업상태명  폐업년도 폐업일자  위치  \
# 0            라캄파넬라         경양식  일반음식점  20140508      영업   NaN  NaN  광주
# 1               명가          한식  일반음식점  20140319      영업   NaN  NaN  광주
# 2             승진이네          한식  일반음식점  20140321      영업   NaN  NaN  광주
# 3          갈비명가아라네          한식  일반음식점  20140612      영업   NaN  NaN  광주
# 4              뚱스넥          한식  일반음식점  20120119      영업   NaN  NaN  광주
# 5  투 테이스티(2-TASTY)          한식  일반음식점  20121010      영업   NaN  NaN  광주
# 6             원아가든          한식  일반음식점  19950901      영업   NaN  NaN  광주
# 7             진성회관          한식  일반음식점  20070312      영업   NaN  NaN  광주
# 8             은혜포차  정종/대포집/소주방  일반음식점  20150618      영업   NaN  NaN  광주
# 9            명송생복집          한식  일반음식점  20070711      영업   NaN  NaN  광주
#
#                                  도로명전체주소
# 0           광주광역시 서구 송풍로17번길 5, 1층 (풍암동)
# 1         광주광역시 서구 내방로350번길 10, 1층 (화정동)
# 2       광주광역시 서구 월드컵4강로116번길 5, 1층 (화정동)
# ...

# %%
disclosed = (df['상세영업상태명']=='폐업'& df['폐업년도']=='2016')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      52 def rand_(left, right):
# ---> 53     return operator.and_(right, left)
#      54
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1268                 try:
# ...

# %%
disclosed1 = df.loc[disclosed]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-26-5d39d849e879> in <module>
# ----> 1 disclosed1 = df.loc[disclosed]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1797             return self._get_slice_axis(key, axis=axis)
# ...

# %%
disclosed3 = (disclosed1['폐업년도']=='2016')
