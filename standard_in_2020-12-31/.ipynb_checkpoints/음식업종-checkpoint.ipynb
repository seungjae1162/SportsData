# %%
#필요한 라이브러리(패키지) import

import pandas as pd
import numpy as np
import csv

# 시각화 패키지
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'

# %matplotlib inline

# %%
# LOCALDATA의 체육시설 업종(https://www.localdata.go.kr/devcenter/dataDown.do?menuNo=20001) 16개 CSV파일 다운
## EXCEL에서 필요없는 칼럼 삭제(37개 -> 14개)
## CSV파일 읽음

df= pd.read_csv("C:/Users/seung/Desktop/2020년도/NanoD/github/SportsData/SportsData/standard_in_2020-12-31/csv/food.csv",encoding='cp949')

# %%
df.tail(10)
# Out:
#                 사업장명  업태구분명 개방서비스명     인허가일자 상세영업상태명  폐업년도      폐업일자  위치  \
# 84803           낚시사랑     한식  일반음식점  20190627      폐업  2020  20200512  인천
# 84804     별헤는밤 대구직영점  호프/통닭  일반음식점  20190627      폐업  2020  20200210  대구
# 84805      봉선약산녹색흑염소     한식  일반음식점  20190627      폐업  2019  20191128  광주
# 84806            소담뜰     한식  일반음식점  20190627      폐업  2020  20201029  충청
# 84807   우리음식연구회(축제장)     한식  일반음식점  20190819      폐업  2019  20190901  충청
# 84808       너 곱닭 남구점     한식  일반음식점  20190819      폐업  2020  20200609  인천
# 84809       이서빈365푸드     기타  일반음식점  20190819      폐업  2020  20200514  경상
# 84810        오반장 떡볶이     분식  일반음식점  20190819      폐업  2020  20200330  서울
# 84811     양평옛날경양식돈까스     한식  일반음식점  20190819      폐업  2020  20200428  경기
# 84812  오색고추식당(고추정식당)     한식  일반음식점  20190826      폐업  2019  20190902  충청
#
#                                                  도로명전체주소
# 84803                      인천광역시 옹진군 영흥면 영흥남로9번길 311, 식당
# ...

# %%
df14 = df['폐업년도'].value_counts(ascending=True)
df14 = pd.DataFrame(df14)
df14.columns = ['폐업 수']
df15 = df14.T
df15
# Out:
#        2016   2020   2017   2018   2019
# 폐업 수  14813  15953  17156  17673  19218

# %%
df14
# Out:
#        폐업 수
# 2016  14813
# 2020  15953
# 2017  17156
# 2018  17673
# 2019  19218

# %%
#년도별 폐업 갯수 막대그래프화

ax = sns.barplot(data=df15)
ax.set_xlabel('년도')
ax.set_title('연도별 음식점 폐업 총 수')
plt.grid(False)

#저장 코드
fig = ax.get_figure()
fig.savefig("연도별 음식점 폐업 총 수.png")

plt.show()
